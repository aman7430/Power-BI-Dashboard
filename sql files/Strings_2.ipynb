# %% [markdown]
# # ASSIGNMENT OPERATORS IN PYTHON

# %%
#Examples of Assignment Operators
a=10

# %%
#Assign Value
b=a
print(b)
# Out:
# 10

# %%
#Add and assign value(it means b=b+a)
b+=a
print(b)
# Out:
# 20

# %%
#Subtract and assisgn value
b-=a
print(b)
# Out:
# 10

# %%
#Multiply and assign
b*=a
print(b)
# Out:
# 100

# %% [markdown]
# # IDENTITY OPERATORS IN PYTHON

# %%
a=10
b=20
c=a

print(a is not b)
print(a is c)
# Out:
# True
# True

# %% [markdown]
# # MEMBERSHIP OPERTAORS IN PYTHON

# %%
#In Python, in and not in are the membership operators that are used to test whe
# Python program to illustrate
#'not in' Operator
x=24
y=20
list=[10,20,30,40,50]

if(x not in list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")
if(y in list):
    print("y is present in given list")
else:
    print("y is Not in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %% [markdown]
# # CONDITIONAL STATEMENT

# %%
"""There comes situations in real life when we need to make some decisions and based on these decisions, 
we decide what should we do next"""

#TYPES OF CONTROL FLOW IN PYTHON
"""In 
"""
# Out:
# 'In \n'

# %%
#Python Program to illustrate to If statement

i=20
if(i>15):
    print(i,"is greater than 15")
print(i,"I am not in if")
# Out:
# 20 is greater than 15
# 20 I am not in if

# %%
#Python Program to illustrate If else statement
#!/usr/bin/python

i=20
if(i<15):
    print("i is smaller than 15")
    print("i'm in else Block")

else:
    print("i is greater than 15")
    print("i'm in else Block")
print("i'm not in if and not in else Block")
# Out:
# i is greater than 15
# i'm in else Block
# i'm not in if and not in else Block

# %%
#Python Program to illustrate if-elif-elsestatement
#!/usr/bin/python

i=20
if(i==10):
    print("i is 10")
elif(i==15):
    print("i is 15")

# %%
#Python program to illustrate If statement

i=10
if(i==10):
    #First if statement
    if(i<15):
        print("i is smaller than 15")
        
    #Nested-if statement
    #Will only be executed if statement above
    #it is true
    if(i<12):
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
#Write a python program to input 3 values from user and print the greatest number

# %%
a=int(input("Enter a number=, "))
b=int(input("Enter a number=, "))
c=int(input("Enter a number=, "))
if(a>b and a>c):
    print("a is the greatest number")
elif(b>c and b>a):
    print("b is the greatest number")
else:
    print("c is the greatest number")
# Out:
# Enter a number=, 10
# Enter a number=, 30
# Enter a number=, 20
# b is the gretaest number

# %% [markdown]
# # SHORT HAND IF OR IF ELSE STATEMENT

# %%
#Python Program to illustrate short hand if

# %%
#Python Program to illustrate short hand if-else
i=10
print(True) if i<15 else print(False)
# Out:
# True

# %%
x,y=input("Enter A and B=",  ).split()
# Out:
# Enter A and B=12 12

# %% [markdown]
# # CHAINING COMPARISION OPERATORS IN PYTHON

# %%
#Python code to illustrate
#chaining comparision operators
x=5
print(1<x<10)
print(10<x<20)
print(x<10<x*10<100)
print(10>x<=9)
print(5==x>4)
# Out:
# True
# False
# True
# True
# True

# %% [markdown]
# # LOOPING ITERATION

# %%
#Python for loops is used for sequential traversal i.e. it is used for iterating over an iterable like Strring, Tuple, List, Set, or Dictionary.

#Here the iterable is a colledction of objects like ;lists and tuples.The indented segments inside the for loops are executed once for each item in an iterable. The variable var takes the value of the next item of the iterable each ti,e through the loop.

# %%
#Python program to illustrate
#Iterating over a lsit

l=["M", "B", "A"]
for i in l:
    print(i)
# Out:
# M
# B
# A

# %% [markdown]
# # Python for loop in Python String

# %%
#Iterating over a String     //'in' is used to run as losng as the list and tuple holds the value// 
print("String Iteration")

s="MBA-AI&DS"
for i in s:     
    print(i)
# Out:
# String Iteration
# M
# B
# A
# -
# A
# I
# &
# D
# S

# %% [markdown]
# # Python For Loops with a Step Size

# %%
for i in range(0,10,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
num=int(input("Enter a number"))
for i in range(1,11):
    print(num, "*", i, "=", num*i)
# Out:
# Enter a number2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
#Write a Python Program to add the numbers from 1 to 10
num=0
for i in range(1,11):
    num=num+i   #or num+=i
print(num)
# Out:
# 55

# %%
#Write a program to input from a user that a person is travelling or not, if it is yes then ask for the passenger number and their name, age and gender
a=int(input("enter if a person is travelling or not 1 for yes and 0 for not"))
if(a==1):
    num=int(input("Enter the number of passengers"))
    
    if (num>1):
    
        for i in range(1,num+1):
            name=input("Enter the passenger name")
            age=int(input("Enter its age"))
            gen=input("Enter the gender")
            print("Name=",name, "Age=",age, "Gender=",gen)
    else:
        name=input("Enter the passenger name=")
        age=int(input("Enter its age="))
        gen=input("Enter the gender=")
        print("Name=",name, "Age=",age, "Gender=",gen)
else:
    print("No Passengers are travelling")
# Out:
# enter if a person is travelling or not 1 for yes and 0 for not1
# Enter the number of passengers3
# Enter the passenger namekartik
# Enter its age24
# Enter the genderm
# Name= kartik Age= 24 Gender= m
# Enter the passenger nameshiv
# Enter its age46
# Enter the genderm
# Name= shiv Age= 46 Gender= m
# Enter the passenger nameparsun
# Enter its age23
# Enter the genderm
# Name= parsun Age= 23 Gender= m

# %% [markdown]
# # Python For Loop inside a For Loop

# %%
for i in range(1,4):
    for j in range(1,4):
        print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %% [markdown]
# # Python For Loop with Zip()

# %%
fruits=["apple", "banana", "cherry"]

# %% [markdown]
# # Pythons for Loop with Continue Statement

# %%
#Print all letters except 'r' and 's'

for letter in 'GraphicEraUniversity':
    if letter=='r' or letter=='s':
        continue
    print('Current Letter :', letter)
# Out:
# Current Letter : G
# Current Letter : a
# Current Letter : p
# Current Letter : h
# Current Letter : i
# Current Letter : c
# Current Letter : E
# Current Letter : a
# Current Letter : U
# Current Letter : n
# Current Letter : i
# Current Letter : v
# Current Letter : e
# Current Letter : i
# Current Letter : t
# Current Letter : y

# %% [markdown]
# # Python For Loop with Break Statement

# %%
for letter in 'GraphicEraUniversity':
    #break the loop as soon as it sees 'r'
    #or 's'
    if letter=='r' or letter=='s':
        break
print("Current Letter :", letter)
# Out:
# Current Letter : r

# %% [markdown]
# # Python For Loop with Pass Statement

# %%
#An empty loop
for letter in 'GraphicEraUniversity':
    pass
print('Last letter :',letter)
# Out:
# Last letter : y

# %%
#Python Program to
for i in range(1,6):
    for j in range(i,i+1):
        print("*")
# Out:
# *
# *
# *
# *
# *

# %%
#WAP to add the digits 5670(5+6+7+0)
#WAP to reverse a digit
#

# %% [markdown]
# # While Loop

# %%
#python program to illustrate
#while loop
count=0
while(count<3):
    count+=1
    print("Hello Students")
# Out:
# Hello Students
# Hello Students
# Hello Students

# %%
#checks if list still
#contains any element
a=[1,2,3,4]

while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %% [markdown]
# # with the continue statement we can stop the current iteration, and continue with the next

# %%
i=0
while i<6:
    i+=1
    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# # with the break statement we can stop the loop even if the while condition is true

# %%
i=0
while i<6:
    print(i)
    if i==3:
         break
    i+=1
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# # with the else statement we can run a block  of code once when the condition no longer is true

# %%
i=1
while i<6:
    print(i)
    i+=1
else:
    print("i is no longer than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer than 6

# %% [markdown]
# # Sentinel Controlled Statement

# %%
a=int(input('Enter a number (-1 to quit):'))

while a!=-1:
    a=int(input('Enter a number (-1 to quit):'))
# Out:
# Enter a number (-1 to quit):2
# Enter a number (-1 to quit):3
# Enter a number (-1 to quit):-1

# %%
#enter an integer number and convert to binary and do a left shift position for two position

# %%
num=int(input("Enter the number: "))
x=bin(num)
y=x+'00'
y
# Out:
# Enter the number: 11
# '0b101100'

# %% [markdown]
# # Creating a Function in Python
# We can create a user-defined function in Python, using the def keyword.We can add any type of functionalities and properties to it as we require

# %% [markdown]
# ### Python Function Declaration
# ##### The syntax to declare a function is:

# %%
def function_name(parameters):
 
  # statement

# %%
# A Python function
def fun():
    print("Welcome to Python Class")

# %%
# Asimple Python function
def fun():
    print("Welcome to Python Class")
    
    
# Driver code to call a function
fun()
# Out:
# Welcome to Python Class

# %% [markdown]
# # Python Function with Parameters

# %%
def add(num1, num2):
    
    num3=num1+num2
    return num3

# Driver code
num1,num2=5,15
ans=add(num1,num2)

print("The addition of", num1, "and", num2, "results", ans)
print(f"The addition of {num1} and {num2} results {ans}.")
# Out:
# The addition of 5 and 15 results 20
# The addition of 5 and 15 results 20.

# %%
# A simple Python function to check
# whether x is even or odd
def evenOdd(x):
    if(x%2==0):
        print("even")
    else:
        print("odd")
        
# Driver code to call the function
evenOdd(2)
evenOdd(3)
# Out:
# even
# odd

# %% [markdown]
# ### Pass by Reference

# %%
# Here x is a new reference to same list 'lst'
#function me uske value ki jagah uski address ko pass karna

def myFun(x):
    x[0]=20
    
# Driver Code (Note that list is modified)
# after function
lst=[10, 11, 12, 13, 14, 15]
myFun(lst)
print(lst)
# Out:
# [20, 11, 12, 13, 14, 15]

# %%
# WAP to define a function to swap the values entered by the user
def swapVal(a,b):
    x=a
    y=b
    temp1=x
    x=y
    y=temp1
    return(x,y)
nom1=int(input("Enter a number"))
nom2=int(input("Enter another number"))
swapVal(nom1,nom2)
# Out:
# Enter a number5
# Enter another number10
# (10, 5)

# %% [markdown]
# ### Generator Function in Python
# A generator function in Python is defined like a normal function, but whnever it needs to generate a value, it does so with the yield keyword rather than return. If the body of a def contains yield, the function automatically becomes a python generator function.

# %%
# A generator function that yields 1 for first time,
# 2 second time and 3 third time
def simpleGeneratorFun():
    yield 1
    yield 2
    yield 3
    
#Driver code to check above generator function 
for value in simpleGeneratorFun():
    print(value)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Python Lambda
# In Python, an anonymous functiion means that a function is without a name. As we already know that def
# keyword is used to define the normal functions and the lambda keyword is used to create anonymous functions.

# %%
calc=lambda num: "Even number" if num%2==0 else "Odd Number"
print(calc(20))
# Out:
# Even number

# %% [markdown]
# ### Python lambda properties
#
# 1)This function can have any number of arguments but only one expression, which is evaluated and returned
#
# 2)One is free to use lambda function objeects are required.
#
# 3)You need to keep in your knowledge that lambda functions are syntactically restricted to a single expression.

# %%
# Difference between lambda and normal function call

def cube(y):
    print(f"Finding cube of number:{y}")
    return y*y*y

lambda_cube=lambda num:num**3

#invoking simple function
print("involving function defined with def keyword:")
print(cube(30))
print(lambda_cube(2))
# Out:
# involving function defined with def keyword:
# Finding cube of number:30
# 27000
# 8

# %%
#Another example

#Example list
my_list=[1, 2, 3, 4, 5]

#Use lambda to filter out even numbers from the list
new_list=list(filter(lambda x: x % 2 !=0, my_list))

#Print the new list
print(new_list)
# Out:
# [1, 3, 5]

# %% [markdown]
# ### Global and Local Variables in Python
#
# Python Global variables are those which are not defined inside any function and have a global
# scope whereas Python local variables are those which are defined inside a function and their scope is limited to that function only. In other words, we an say that local variables are
