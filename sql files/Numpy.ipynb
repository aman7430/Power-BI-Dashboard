# %% [markdown]
# #### Without Function

# %%
w1, w2, w3=0.3, 0.2, 0.5

region=['kanto', 'johto', 'hoenn', 'sinnoh', 'unova']
temp=[73, 91, 87, 102, 69]
rainfall=[67, 88, 134, 43, 96]
humidity=[43, 64, 58, 37,70]

for i in range(0,5,1):
    region[i]=temp[i]*w1+rainfall[i]*w2+humidity[i]*w3
    print(region[i])
# Out:
# 56.8
# 76.9
# 81.9
# 57.699999999999996
# 74.9

# %%
w1, w2, w3=0.3, 0.2, 0.5

# %%
region=['kanto', 'johto', 'hoenn', 'sinnoh', 'unova']
temp=[73, 91, 87, 102, 69]
rainfall=[67, 88, 134, 43, 96]
humidity=[43, 64, 58, 37,70]

# %%
for i in range(0,5,1):
    region[i]=temp[i]*w1+rainfall[i]*w2+humidity[i]*w3
    print(region[i])
# Out:
# 56.8
# 76.9
# 81.9
# 57.699999999999996
# 74.9

# %% [markdown]
# #### or

# %% [markdown]
# #### With Function

# %%
w1, w2, w3=0.3, 0.2, 0.5

# %%
weights=[w1, w2, w3]

# %%
kanto=[73, 67, 43]
johto=[91, 88, 64]
sinnoh=[87, 134, 58]
hoenn=[102, 43, 37]
unova=[69, 96, 70]

# %%
zip(kanto,weights)

# %%
zip(kanto,weights)

# %%
def crop_yield(region, weights):
    result=0
    for x, w in zip(region,weights):
        result+=x*w
        return result

# %%
crop_yield(kanto, weights)
# Out:
# 21.9

# %%
crop_yield(johto, weights)
# Out:
# 27.3

# %%
crop_yield(sinnoh, weights)
# Out:
# 26.099999999999998

# %%
crop_yield(hoenn, weights)
# Out:
# 30.599999999999998

# %%
crop_yield(unova, weights)
# Out:
# 20.7

# %% [markdown]
# #### Testing with functions

# %%
w1, w2, w3=0.3, 0.2, 0.5

# %%
region=['kanto', 'johto', 'hoenn', 'sinnoh', 'unova']
temp=[73, 91, 87, 102, 69]
rainfall=[67, 88, 134, 43, 96]
humidity=[43, 64, 58, 37,70]

# %%
def test(a,b,c,t,r,h): 
    return (t*a+r*b+h*c)

# %%
for i in range(0,5,1):
    reg=test(w1, w2, w3, temp[i], rainfall[i], humidity[i])
    print(f"{region[i]}= ", reg)
# Out:
# kanto=  56.8
# johto=  76.9
# hoenn=  81.9
# sinnoh=  57.699999999999996
# unova=  74.9

# %% [markdown]
# # Numpy

# %%
kanto=[73, 67, 43]
johto=[91, 88, 64]
sinnoh=[87, 134, 58]
hoenn=[102, 43, 37]
unova=[69, 96, 70]

# %%
w1, w2, w3=0.3, 0.2, 0.5

# %%
import numpy as np

# %%
kanto
# Out:
# [73, 67, 43]

# %% [markdown]
# ### We can now use the np.array function to create Numpy arrays

# %%
kanto=np.array([73, 67, 43])

# %%
kanto
# Out:
# array([73, 67, 43])

# %%
type(kanto)
# Out:
# numpy.ndarray

# %%
#Ek square bracket hai matlab one dimensio hai par 3 column kyuki 3 elements hai

# %%
weights=np.array([w1, w2, w3])

# %%
weights
# Out:
# array([0.3, 0.2, 0.5])

# %%
type(johto)
# Out:
# list

# %%
type(weights)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Just like lists, Numpy arrays support the indexing notation[]

# %%
weights[0]
# Out:
# 0.3

# %%
kanto[2]
# Out:
# 43

# %% [markdown]
# # Operations on Numpy arrays

# %%
#We can now compute the dot product of the two vectors using np.dot function

# %%
np.dot(kanto, weights)
# Out:
# 56.8

# %%
#Python lists
arr1= list(range(1000000))
arr2= list(range(1000000, 2000000))

#Numpy arrays
arr1_np=np.array(arr1)
arr2_np=np.array(arr2)

# %%
arr1_np
# Out:
# array([     0,      1,      2, ..., 999997, 999998, 999999])

# %%
arr2_np
# Out:
# array([1000000, 1000001, 1000002, ..., 1999997, 1999998, 1999999])

# %%
# %%time 
result=0
for x1, x2 in zip(arr1,arr2):
    result+=x1*x2
result
# Out:
# CPU times: total: 266 ms
# Wall time: 382 ms
# 833332333333500000

# %%
# %%time 
result1=np.dot(arr1_np, arr2_np)
result1
# Out:
# CPU times: total: 0 ns
# Wall time: 1.45 ms
# -1942957984

# %% [markdown]
# # MULTI-DIMENSIONAL NUMPY ARRAYS

# %%
import numpy as np      
      #3,3,2,2

# %%
arr3= np.array([[[1,2],[2,3],
                 [4,5],[3,4],
                 [4,4],[6,7]]],
                
                [[[1,2],[2,3],
                 [4,5],[3,4],
                 [4,4],[6,7]],
                
                 [[[1,2],[2,3],
                 [4,5],[3,4],
                 [4,4],[6,7]])

# %%
arr3.shape
# Out:
# (3, 6, 2)

# %%
arr3 = np.array([[[1,2,3],[3,4,5]],
                 [[1,2,3],[3,4,5]]
                 
    
])

# %%
arr3.shape
# Out:
# (2, 2, 3)

# %%
arr3 = np.array([[[3]],
                 [[4]],
                 [[5]].
    
])
# Out:
#   Cell In[17], line 5
#     ])
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # WORKING WITH CSV DATA FILES
